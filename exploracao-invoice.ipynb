# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/invoice/invoice.csv')

# %%
df1 = pd.read_csv('./data/invoice/invoice-log.csv')

# %% [markdown]
# # Análise invoice

# %%
df.shape
# Out:
# (616422, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616422 entries, 0 to 616421
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             616422 non-null  int64
#  1   status         616422 non-null  object
#  2   created        616422 non-null  object
#  3   nominalAmount  616422 non-null  int64
#  4   amount         616422 non-null  int64
#  5   due            616422 non-null  object
#  6   fine           616422 non-null  float64
#  7   interest       616422 non-null  float64
#  8   expiration     616422 non-null  object
#  9   name           616422 non-null  object
#  10  taxId          616422 non-null  object
#  11  workspaceId    616422 non-null  int64
#  12  brcode         610102 non-null  object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 61.1+ MB

# %%
df.describe()
# Out:
#                  id  nominalAmount        amount           fine  \
# count  6.164220e+05   6.164220e+05  6.164220e+05  616422.000000
# mean   5.628552e+15   4.662002e+05  4.664410e+05       4.887585
# std    6.480662e+14   1.456025e+06  1.457077e+06       2.706585
# min    4.503601e+15   1.000000e+00  0.000000e+00       0.000000
# 25%    5.068026e+15   2.914700e+04  2.914700e+04       2.000000
# 50%    5.630313e+15   5.901200e+04  5.901150e+04       4.545603
# 75%    6.192073e+15   8.905000e+04  8.904975e+04       7.268864
# max    6.755398e+15   5.234578e+07  5.234578e+07       9.999986
#
#             interest   workspaceId
# count  616422.000000  6.164220e+05
# mean        2.649226  4.916212e+15
# std         1.295987  3.067206e+14
# min         0.000000  4.800539e+15
# 25%         1.357498  4.800539e+15
# 50%         2.574086  4.800539e+15
# 75%         3.786747  4.800539e+15
# max         4.999995  6.301997e+15

# %%
df.head()
# Out:
#                  id   status                         created  nominalAmount  \
# 0  4678987875876864  created  2024-08-29 15:03:25.194125 UTC        4291554
# 1  6508575224496128  created  2024-08-29 15:03:25.193936 UTC        9592736
# 2  5382675317653504  created  2024-08-29 15:03:25.193727 UTC         305293
# 3  5945625271074816  created  2024-08-29 15:03:25.193229 UTC        4659891
# 4  6227100247785472  created  2024-08-29 15:03:25.193144 UTC        5093695
#
#     amount                             due  fine  interest  \
# 0  4291554  2024-08-31 15:03:25.178125 UTC   2.0       1.0
# 1  9592736  2024-08-31 15:03:25.178056 UTC   2.0       1.0
# 2   305293  2024-08-31 15:03:25.177985 UTC   2.0       1.0
# 3  4659891  2024-08-31 15:03:25.177911 UTC   2.0       1.0
# 4  5093695  2024-08-31 15:03:25.177797 UTC   2.0       1.0
#
#                        expiration                name               taxId  \
# 0  2024-10-29 15:03:25.178125 UTC  Terrance Templeman      131.026.712-09
# ...

# %% [markdown]
# # Análise invoice-log

# %%
df1.shape
# Out:
# (1851462, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1851462 entries, 0 to 1851461
# Data columns (total 15 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   id                     int64
#  1   created                object
#  2   invoice_id             int64
#  3   invoice_status         object
#  4   invoice_created        object
#  5   invoice_nominalAmount  int64
#  6   invoice_amount         int64
#  7   invoice_due            object
#  8   invoice_fine           float64
#  9   invoice_interest       float64
#  10  invoice_expiration     object
#  11  invoice_name           object
#  12  invoice_taxId          object
#  13  invoice_workspaceId    int64
#  14  invoice_brcode         object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 211.9+ MB

# %%
df1.describe()
# Out:
#                  id    invoice_id  invoice_nominalAmount  invoice_amount  \
# count  1.851462e+06  1.851462e+06           1.851462e+06    1.851462e+06
# mean   5.629499e+15  5.628463e+15           4.446035e+05    4.447594e+05
# std    6.489378e+14  6.481602e+14           1.412379e+06    1.413104e+06
# min    4.503601e+15  4.503601e+15           0.000000e+00    0.000000e+00
# 25%    5.068657e+15  5.067836e+15           2.901500e+04    2.901300e+04
# 50%    5.630696e+15  5.630206e+15           5.870500e+04    5.870400e+04
# 75%    6.191743e+15  6.191976e+15           8.857600e+04    8.857600e+04
# max    6.755399e+15  6.755398e+15           5.234578e+07    5.234578e+07
#
#        invoice_fine  invoice_interest  invoice_workspaceId
# count  1.851462e+06      1.851462e+06         1.851462e+06
# mean   4.903241e+00      2.658118e+00         4.912580e+15
# std    2.705509e+00      1.293806e+00         3.013358e+14
# min    0.000000e+00      0.000000e+00         4.800539e+15
# ...

# %%
df1.head()
# Out:
#                  id                         created        invoice_id  \
# 0  5110404925620224  2024-08-29 15:03:33.066217 UTC  5252544972455936
# 1  5673354879041536  2024-08-29 15:03:33.066076 UTC  5393282460811264
# 2  4547454972198912  2024-08-29 15:03:33.065973 UTC  5815494925877248
# 3  6693701669617664  2024-08-29 15:03:33.065885 UTC  6237707390943232
# 4  5567801762775040  2024-08-29 15:03:33.065801 UTC  6519182367653888
#
#   invoice_status                 invoice_created  invoice_nominalAmount  \
# 0        overdue  2024-08-27 15:03:32.277253 UTC                9028505
# 1        overdue  2024-08-27 15:03:32.276734 UTC                 221720
# 2        overdue  2024-08-27 15:03:32.277142 UTC                9609608
# 3        overdue  2024-08-27 15:03:32.275345 UTC                5700174
# 4        overdue  2024-08-27 15:03:32.276874 UTC                3156770
#
#    invoice_amount                     invoice_due  invoice_fine  \
# ...
